# %%
import matplotlib
import matplotlib.image as image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = 'img.png'
image = image.imread(img)
image
plt.imshow(image)

# %%
# quay hinh nguoc chieu kim
X = np.rot90(image, 2)
plt.imshow(X)

# %%
#quay cung chieu
X = np.rot90(image, -2)
plt.imshow(X)

# %%
# lat nguoc hinh`
plt.imshow(image[::-1])

# %%
# lat ngang hinh
plt.imshow(image[:,::-1])

# %%
#tao hinh random
X = np.random.random((100,100,3))
random = plt.imshow(X)

# %%
# giam kich thuoc anh con  60x40
X = plt.imshow(random[1:40,1:60])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-4519a8d15151> in <module>
#       1 # giam kich thuoc anh con  60x40
# ----> 2 plt.imshow(random[1:40,1:60])
#
# TypeError: 'AxesImage' object is not subscriptable
