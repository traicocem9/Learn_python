# %%
from numpy import random
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as image

# %%
img = 'img.png'
image = image.imread(img)
image
plt.imshow(image)

# %%
# quay hinh nguoc chieu kim
X = np.rot90(image, 2)
plt.imshow(X)

# %%
#quay cung chieu
X = np.rot90(image, -2)
plt.imshow(X)

# %%
# lat nguoc hinh`
plt.imshow(image[::-1])

# %%
# lat ngang hinh
plt.imshow(image[:,::-1])

# %%
#tao hinh random
X = np.random.random((100,100,3))
random = plt.imshow(X)

# %%
# giam kich thuoc anh con  60x40
X = plt.imshow(X[1:40,1:60])
